# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
#
# * 根據範例使用 API 取出 高雄市小港區 2019 年 空氣品質 資料，並用一個適合的資料結構儲存
# * Hint: 將所有資料存在一個變數當中

# %%
import requests
url = 'https://taqm.epa.gov.tw/taqm/tw/MonthlyAverage.aspx'
payload = {
    'ScriptManager1': 'ctl05$UpdatePanel1|ctl05$btnQuery', 
    '__VIEWSTATE': '...',
    '__VIEWSTATEGENERATOR': '0C858E1A',
    '__EVENTVALIDATION': '...',
    'ctl05$ddlSite': 58,
    'ctl05$ddlYear': 2019, 
    'ctl05$btnQuery': '查詢'
}
r = requests.post(url, data=payload)
r.status_code
# Out:
# 200

# %% [markdown]
# ![](https://imgur.com/obLkbFe.jpg)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')
table = soup.find('table', class_='TABLE_G')
print(table)
# Out:
# <table align="Center" border="1" cellpadding="3" cellspacing="0" class="TABLE_G" id="ctl05_gv" rules="all" style="border-color:Black;border-width:1px;border-style:None;border-collapse:collapse;">
# <tr style="color:Black;font-weight:normal;">
# <th scope="col">監測項目</th><th scope="col">單位</th><th scope="col">監測日期</th><th scope="col">監測值</th><th scope="col">標註</th>
# </tr><tr style="color:Black;">
# <td class="no-alt" rowspan="12" style="white-space:nowrap;" valign="top">SO2</td><td class="no-alt" rowspan="12" valign="top">ppb</td><td>2019/01</td><td>4.10</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2019/02</td><td>3.30</td><td> </td>
# </tr><tr style="color:Black;">
# <td>2019/03</td><td>3.90</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2019/04</td><td>3.40</td><td> </td>
# </tr><tr style="color:Black;">
# <td>2019/05</td><td>3.30</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2019/06</td><td>4.10</td><td> </td>
# ...

# %%
d = dict()
subKey = dict()
trueKey = ''
getTr = table.find_all('tr',attrs={'style':'color:Black;'})
#rawKeys = table.find_all(attrs = {"style":"white-space:nowrap;"})
for Tr in getTr:
    #print(Tr)
    parseTr = Tr.find_all('td',attrs={'style':'white-space:nowrap;'})
    if len(parseTr) > 0:
        if len(subKey) > 0:
            d[trueKey]=subKey
        trueKey = parseTr[0].text
        subKey = dict()
        parseTd = Tr.find_all('td')
        subKey[parseTd[2].text]=parseTd[3].text
        #print(Tr)
    else:
        #subKey
        #print(Tr)
        parseTd = Tr.find_all('td')
        subKey[parseTd[0].text]=parseTd[1].text
print(d)
# Out:
# {'SO2': {'2019/01': '4.10', '2019/02': '3.30', '2019/03': '3.90', '2019/04': '3.40', '2019/05': '3.30', '2019/06': '4.10', '2019/07': '4', '2019/08': '4.60', '2019/09': '3.50', '2019/10': '3.20', '2019/11': '3.60', '2019/12': '3'}, 'CO': {'2019/01': '0.67', '2019/02': '0.48', '2019/03': '0.50', '2019/04': '0.39', '2019/05': '0.38', '2019/06': '0.24', '2019/07': '0.28', '2019/08': '0.33', '2019/09': '0.32', '2019/10': '0.36', '2019/11': '0.46', '2019/12': '0.54'}, 'O3': {'2019/01': '24.70', '2019/02': '29.40', '2019/03': '29.20', '2019/04': '30.40', '2019/05': '28.60', '2019/06': '16.30', '2019/07': '15.50', '2019/08': '19.70', '2019/09': '35.70', '2019/10': '44', '2019/11': '34.80', '2019/12': '22.30'}, 'PM10': {'2019/01': '78', '2019/02': '57', '2019/03': '52', '2019/04': '42', '2019/05': '35', '2019/06': '20', '2019/07': '24', '2019/08': '27', '2019/09': '35', '2019/10': '50', '2019/11': '63', '2019/12': '54'}, 'NOx': {'2019/01': '38.01', '2019/02': '25.62', '2019/03': '27.84', '20
# ...

# %%
d = dict()
subKey = dict()
trueKey = ''
getTr = table.find_all('tr',attrs={'style':'color:Black;'})
#rawKeys = table.find_all(attrs = {"style":"white-space:nowrap;"})
for Tr in getTr:
    #print(Tr)
    parseTr = Tr.find_all('td',attrs={'style':'white-space:nowrap;'})
    if len(parseTr) > 0:
        if len(subKey) > 0:
            d[trueKey]=subKey
        trueKey = parseTr[0].text
        subKey = dict()
        parseTd = Tr.find_all('td')
        subKey[parseTd[2].text]=parseTd[3].text
        #print(Tr)
    else:
        #subKey
        #print(Tr)
        parseTd = Tr.find_all('td')
        subKey[parseTd[0].text]=parseTd[1].text
print(d)
# Out:
# {'SO2': {'2019/01': '4.10', '2019/02': '3.30', '2019/03': '3.90', '2019/04': '3.40', '2019/05': '3.30', '2019/06': '4.10', '2019/07': '4', '2019/08': '4.60', '2019/09': '3.50', '2019/10': '3.20', '2019/11': '3.60'}, 'CO': {'2019/01': '0.67', '2019/02': '0.48', '2019/03': '0.50', '2019/04': '0.39', '2019/05': '0.38', '2019/06': '0.24', '2019/07': '0.28', '2019/08': '0.33', '2019/09': '0.32', '2019/10': '0.36', '2019/11': '0.46'}, 'O3': {'2019/01': '24.70', '2019/02': '29.40', '2019/03': '29.20', '2019/04': '30.40', '2019/05': '28.60', '2019/06': '16.30', '2019/07': '15.50', '2019/08': '19.70', '2019/09': '35.70', '2019/10': '44', '2019/11': '34.80'}, 'PM10': {'2019/01': '78', '2019/02': '57', '2019/03': '52', '2019/04': '42', '2019/05': '35', '2019/06': '20', '2019/07': '24', '2019/08': '27', '2019/09': '35', '2019/10': '50', '2019/11': '63'}, 'NOx': {'2019/01': '38.01', '2019/02': '25.62', '2019/03': '27.84', '2019/04': '21.83', '2019/05': '22.55', '2019/06': '17.15', '2019/07': '17.
# ...

# %%
import pandas as pd
pd.DataFrame(d)
# Out:
#           SO2    CO     O3 PM10    NOx    NO    NO2   THC  NMHC
# 2019/01  4.10  0.67  24.70   78  38.01  7.95  30.06  2.27  0.27
# 2019/02  3.30  0.48  29.40   57  25.62  4.76  20.86  2.11  0.17
# 2019/03  3.90  0.50  29.20   52  27.84  5.41  22.43  2.12  0.18
# 2019/04  3.40  0.39  30.40   42  21.83  4.16  17.68  2.02  0.14
# 2019/05  3.30  0.38  28.60   35  22.55  4.58  17.98  2.02  0.16
# 2019/06  4.10  0.24  16.30   20  17.15  5.08  12.08  1.92  0.13
# 2019/07     4  0.28  15.50   24  17.71  5.16  12.54  1.93  0.14
# 2019/08  4.60  0.33  19.70   27  19.66  5.17  14.49  1.97  0.15
# 2019/09  3.50  0.32  35.70   35  18.66  3.63  15.03  1.98  0.13
# 2019/10  3.20  0.36     44   50  19.50  3.50  15.99  2.05  0.13
# 2019/11  3.60  0.46  34.80   63  28.99  5.21  23.78  2.15  0.21
# 2019/12     3  0.54  22.30   54  33.84  7.83     26  2.18  0.23
