# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %%
import requests
import json

r = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=true")
#r.text
j = json.loads(r.text)
j
# Out:
# [{'id': 233153070,
#   'title': '賤人！',
#   'excerpt': '今天心血來潮想幫家裡的貓咪拍照，理想的畫面是這樣的，但是大部分的卻拍成這樣，⋯⋯，好吧，要ㄎㄧㄤ是吧？那我們就ㄎㄧㄤ到底吧！，於是，就變成這樣了（´･ω･`）',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T17:57:19.700Z',
#   'updatedAt': '2020-02-27T17:57:19.700Z',
#   'commentCount': 5,
#   'likeCount': 217,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '國立成功大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '0781b13f-9859-4f8e-b2cd-4fd4bd0ba54f',
#     'url': 'https://megapx-assets.dcard.tw/images/3f11940c-5d8e-4002-b008-d2245a407bff/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/3f11940c-5d8e-4002-b008-d2245a407bff/640.jpeg',
# ...

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#len(j)
a=j[0].keys()
#for x in a:
#    print(x)
print('# of data: %d\n'%(len(j)))
print('titles in the data:\n')
for x in a:
    print(x)
# Out:
# # of data: 30
#
# titles in the data:
#
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# gender
# school
# replyTitle
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# layout
# withImages
# withVideos
# media
# reportReasonText
# postAvatar

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for x in j:
    print('標題: %s, 貼文時間: %s, 留言人數: %d, 按讚人數: %d'%(x['title'],x['createdAt'],x['commentCount'],x['likeCount']))
# Out:
# 標題: 賤人！, 貼文時間: 2020-02-27T17:57:19.700Z, 留言人數: 5, 按讚人數: 217
# 標題: 文長 我擁有全世界最棒的貓咪, 貼文時間: 2020-02-27T23:47:16.852Z, 留言人數: 8, 按讚人數: 183
# 標題: 曬照🐿️, 貼文時間: 2020-02-28T03:46:37.460Z, 留言人數: 6, 按讚人數: 128
# 標題: 三腳黑妞；救援孕狗不是件容易的事, 貼文時間: 2020-02-28T04:16:05.721Z, 留言人數: 4, 按讚人數: 89
# 標題: 所以說到底是什麼生物呢, 貼文時間: 2020-02-28T06:28:07.294Z, 留言人數: 3, 按讚人數: 70
# 標題: 求這篇限時的貓咪, 貼文時間: 2020-02-28T06:23:06.364Z, 留言人數: 2, 按讚人數: 56
# 標題: 來曬一下家裡的黑狗🐶, 貼文時間: 2020-02-27T21:10:15.772Z, 留言人數: 7, 按讚人數: 55
# 標題: 朕想怎麼睡 就怎麼睡(˶‾᷄ ⁻̫ ‾᷅˵), 貼文時間: 2020-02-27T19:53:48.404Z, 留言人數: 1, 按讚人數: 53
# 標題: #協尋紅貴賓#懸賞金$5000#請大家幫忙頂上去！, 貼文時間: 2020-02-27T17:05:28.180Z, 留言人數: 6, 按讚人數: 31
# 標題: 柯基犬曬萌照, 貼文時間: 2020-02-28T04:37:56.515Z, 留言人數: 0, 按讚人數: 23
# 標題: 我只是想打個哈欠🥱, 貼文時間: 2020-02-28T16:44:58.714Z, 留言人數: 3, 按讚人數: 19
# 標題: 同學我要妮的貓貓！！！, 貼文時間: 2020-02-28T07:26:54.480Z, 留言人數: 1, 按讚人數: 17
# 標題: 看那顫抖的小眼眶, 貼文時間: 2020-02-27T22:52:19.976Z, 留言人數: 4, 按讚人數: 17
# 標題: 家有兩隻貓(⌯͒⁍̩̩᷄ ɪ ⁍̩̩᷄ฅ͒), 貼文時間: 2020-02-28T16:04:47.921Z, 留言人數: 1, 按讚人數: 16
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
rf = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=false")
#r.text
jf = json.loads(rf.text)
commentctrue = 0
likectrue = 0
commentcfalse = 0
likecfalse = 0

for x in j:
    commentctrue += x['commentCount']
    likectrue += x['likeCount']
    
for x in jf:
    commentcfalse += x['commentCount']
    likecfalse += x['likeCount']
    
print('熱門 平均留言: %.2f, 平均按讚: %.2f; 非熱門 平均留言: %.2f, 平均按讚: %.2f'%(commentctrue/len(j), likectrue/len(j), commentcfalse/len(jf), likecfalse/len(jf)))
# Out:
# 熱門 平均留言: 2.50, 平均按讚: 36.50; 非熱門 平均留言: 1.60, 平均按讚: 3.70
